# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
import My_Covid_data as cd

# %%
dataC = cd.Get_Covid_data('Buchanan County',"MO")

# %%
counties = cd.Get_counties("MO")

# %%
dataV = cd.Covid_vaccine('Buchanan County',"MO")

# %%
plt.figure(figsize=(13,6))
plt.plot(dataV.Series_Complete_12PlusPop_Pct, label='12+')
plt.plot(dataV.Series_Complete_18PlusPop_Pct, label='18+')
plt.plot(dataV.Series_Complete_65PlusPop_Pct, label='65+')
plt.legend()
plt.show()

# %%
dataV = cd.Covid_vaccine('Platte County',"MO")
plt.figure(figsize=(13,6))
plt.plot(dataV.Series_Complete_12PlusPop_Pct, label='12+')
plt.plot(dataV.Series_Complete_18PlusPop_Pct, label='18+')
plt.plot(dataV.Series_Complete_65PlusPop_Pct, label='65+')
plt.legend()
plt.show()

# %%
dataVote = pd.read_csv('Data/countypres_2000-2020.csv')
dataVote.head(10)
# Out:
#    year    state state_po county_name  county_fips     office       candidate  \
# 0  2000  ALABAMA       AL     AUTAUGA       1001.0  PRESIDENT         AL GORE
# 1  2000  ALABAMA       AL     AUTAUGA       1001.0  PRESIDENT  GEORGE W. BUSH
# 2  2000  ALABAMA       AL     AUTAUGA       1001.0  PRESIDENT     RALPH NADER
# 3  2000  ALABAMA       AL     AUTAUGA       1001.0  PRESIDENT           OTHER
# 4  2000  ALABAMA       AL     BALDWIN       1003.0  PRESIDENT         AL GORE
# 5  2000  ALABAMA       AL     BALDWIN       1003.0  PRESIDENT  GEORGE W. BUSH
# 6  2000  ALABAMA       AL     BALDWIN       1003.0  PRESIDENT     RALPH NADER
# 7  2000  ALABAMA       AL     BALDWIN       1003.0  PRESIDENT           OTHER
# 8  2000  ALABAMA       AL     BARBOUR       1005.0  PRESIDENT         AL GORE
# 9  2000  ALABAMA       AL     BARBOUR       1005.0  PRESIDENT  GEORGE W. BUSH
#
#         party  candidatevotes  totalvotes   version   mode
# ...

# %%
dataVote.columns
# Out:
# Index(['year', 'state', 'state_po', 'county_name', 'county_fips', 'office',
#        'candidate', 'party', 'candidatevotes', 'totalvotes', 'version',
#        'mode'],
#       dtype='object')

# %%
Cols = ['Year', 'State', 'State_po', 'County_name', 'County_fips', 'Office',
       'Candidate', 'Party', 'Candidatevotes', 'Totalvotes', 'Version',
       'Mode']
dataVote.columns = Cols
dataVote
# Out:
#        Year    State State_po County_name  County_fips        Office  \
# 0      2000  ALABAMA       AL     AUTAUGA       1001.0     PRESIDENT
# 1      2000  ALABAMA       AL     AUTAUGA       1001.0     PRESIDENT
# 2      2000  ALABAMA       AL     AUTAUGA       1001.0     PRESIDENT
# 3      2000  ALABAMA       AL     AUTAUGA       1001.0     PRESIDENT
# 4      2000  ALABAMA       AL     BALDWIN       1003.0     PRESIDENT
# ...     ...      ...      ...         ...          ...           ...
# 72612  2020  WYOMING       WY    WASHAKIE      56043.0  US PRESIDENT
# 72613  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 72614  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 72615  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 72616  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
#
#                Candidate        Party  Candidatevotes  Totalvotes   Version  \
# ...

# %%
dataVote.Mode.unique()
# Out:
# array(['TOTAL', 'EARLY VOTE', 'ELECTION DAY', 'PROVISIONAL', 'ABSENTEE',
#        'ADVANCED VOTING', 'PROV', 'ABSENTEE BY MAIL', 'ONE STOP',
#        'FAILSAFE', 'FAILSAFE PROVISIONAL', 'IN-PERSON ABSENTEE',
#        '2ND ABSENTEE', 'EARLY VOTING', 'EARLY', 'MAIL'], dtype=object)

# %%
dataVote2020 = dataVote[dataVote.Year==2020]

# %%
dataVote2020.head()
# Out:
#        Year    State State_po County_name  County_fips     Office  \
# 50524  2020  ALABAMA       AL     AUTAUGA       1001.0  PRESIDENT
# 50525  2020  ALABAMA       AL     AUTAUGA       1001.0  PRESIDENT
# 50526  2020  ALABAMA       AL     AUTAUGA       1001.0  PRESIDENT
# 50527  2020  ALABAMA       AL     BALDWIN       1003.0  PRESIDENT
# 50528  2020  ALABAMA       AL     BALDWIN       1003.0  PRESIDENT
#
#                Candidate       Party  Candidatevotes  Totalvotes   Version  \
# 50524  JOSEPH R BIDEN JR    DEMOCRAT          7503.0     27770.0  20210622
# 50525              OTHER       OTHER           429.0     27770.0  20210622
# 50526     DONALD J TRUMP  REPUBLICAN         19838.0     27770.0  20210622
# 50527  JOSEPH R BIDEN JR    DEMOCRAT         24578.0    109679.0  20210622
# 50528              OTHER       OTHER          1557.0    109679.0  20210622
#
#         Mode
# 50524  TOTAL
# 50525  TOTAL
# 50526  TOTAL
# 50527  TOTAL
# 50528  TOTAL

# %%
dataVote2020[(dataVote2020.Mode=="TOTAL")&(dataVote2020.Candidate=="DONALD J TRUMP")].Candidatevotes.sum()
# Out:
# 58773228.0

# %%
dataVote2020[(dataVote2020.Mode=="TOTAL")&(dataVote2020.Candidate=="JOSEPH R BIDEN JR")].Candidatevotes.sum()
# Out:
# 66194500.0

# %%
dataVote2020[dataVote2020.County_fips==29021].head(30)
# Out:
#        Year     State State_po County_name  County_fips     Office  \
# 60162  2020  MISSOURI       MO    BUCHANAN      29021.0  PRESIDENT
# 60163  2020  MISSOURI       MO    BUCHANAN      29021.0  PRESIDENT
# 60164  2020  MISSOURI       MO    BUCHANAN      29021.0  PRESIDENT
# 60165  2020  MISSOURI       MO    BUCHANAN      29021.0  PRESIDENT
# 60166  2020  MISSOURI       MO    BUCHANAN      29021.0  PRESIDENT
#
#                Candidate        Party  Candidatevotes  Totalvotes   Version  \
# 60162  JOSEPH R BIDEN JR     DEMOCRAT         13445.0     36598.0  20210622
# 60163              OTHER        GREEN           127.0     36598.0  20210622
# 60164       JO JORGENSEN  LIBERTARIAN           529.0     36598.0  20210622
# 60165              OTHER        OTHER            47.0     36598.0  20210622
# 60166     DONALD J TRUMP   REPUBLICAN         22450.0     36598.0  20210622
#
#         Mode
# 60162  TOTAL
# 60163  TOTAL
# 60164  TOTAL
# 60165  TOTAL
# 60166  TOTAL

# %%
dataVote2020[dataVote2020.County_fips==29165].head(30)
# Out:
#        Year     State State_po County_name  County_fips     Office  \
# 60522  2020  MISSOURI       MO      PLATTE      29165.0  PRESIDENT
# 60523  2020  MISSOURI       MO      PLATTE      29165.0  PRESIDENT
# 60524  2020  MISSOURI       MO      PLATTE      29165.0  PRESIDENT
# 60525  2020  MISSOURI       MO      PLATTE      29165.0  PRESIDENT
# 60526  2020  MISSOURI       MO      PLATTE      29165.0  PRESIDENT
#
#                Candidate        Party  Candidatevotes  Totalvotes   Version  \
# 60522  JOSEPH R BIDEN JR     DEMOCRAT         27179.0     57270.0  20210622
# 60523              OTHER        GREEN           182.0     57270.0  20210622
# 60524       JO JORGENSEN  LIBERTARIAN           902.0     57270.0  20210622
# 60525              OTHER        OTHER            90.0     57270.0  20210622
# 60526     DONALD J TRUMP   REPUBLICAN         28917.0     57270.0  20210622
#
#         Mode
# 60522  TOTAL
# 60523  TOTAL
# 60524  TOTAL
# 60525  TOTAL
# 60526  TOTAL
